# %%
import pandas as pd

# %%
df = pd.read_csv("State_wise_Tax_2019.csv")

# %%
df
# Out:
#                     Name Abbreviation  TaxRate  \
# 0                Alabama           al     3.67
# 1                 Alaska           ak     0.00
# 2                Arizona           az     3.52
# 3               Arkansas           ar     4.05
# 4             California           ca     7.75
# 5               Colorado           co     4.63
# 6            Connecticut           ct     5.70
# 7               Delaware           de     4.71
# 8   District of Columbia           dc     7.12
# 9                Florida           fl     0.00
# 10               Georgia           ga     3.50
# 11                Hawaii           hi     6.03
# 12                 Idaho           id     5.00
# 13              Illinois           il     3.75
# 14               Indiana           in     3.30
# 15                  Iowa           ia     4.92
# 16                Kansas           ks     4.33
# 17              Kentucky           ky     4.30
# 18             Louisiana           la     2.02
# ...
